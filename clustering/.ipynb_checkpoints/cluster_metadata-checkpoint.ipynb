# %%
# %pip install spacy

# %%
# %pip install pandas

# %%
# %pip install pyarrow

# %%
# %pip install scispacy
# %pip install sentence_transformers

# %%
# %pip install bertopic
# Out:
# Collecting bertopic
#   Using cached bertopic-0.17.4-py3-none-any.whl.metadata (24 kB)
# Collecting hdbscan>=0.8.29 (from bertopic)
#   Using cached hdbscan-0.8.44-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (15 kB)
# Collecting umap-learn>=0.5.0 (from bertopic)
#   Using cached umap_learn-0.5.12-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: numpy>=1.20.0 in /home/exouser/jupyter-env/lib/python3.12/site-packages (from bertopic) (1.26.4)
# Requirement already satisfied: pandas>=1.1.5 in /home/exouser/jupyter-env/lib/python3.12/site-packages (from bertopic) (3.0.5)
# Collecting plotly>=4.7.0 (from bertopic)
#   Downloading plotly-7.0.0-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: scikit-learn>=1.0 in /home/exouser/jupyter-env/lib/python3.12/site-packages (from bertopic) (1.9.0)
# Requirement already satisfied: sentence-transformers>=0.4.1 in /home/exouser/jupyter-env/lib/python3.12/site-packages (from bertopic) (6.0.0)
# Requirement already satisfied: tqdm>=4.41.1 in /home/exouser/jupyter-env/lib/python3.12/site-packages (from bertopic) (4.70.0)
# Collecting llvmlite>0.36.0 (from bertopic)
#   Downloading llvmlite-0.49.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.0 kB)
# Requirement already satisfied: scipy>=1.0 in /home/exouser/jupyter-env/lib/python3.12/site-packages (from hdbscan>=0.8.29->bertopic) (1.17.1)
# Requirement already satisfied: joblib>=1.0 in /home/exouser/jupyter-env/lib/python3.12/site-packages (from hdbscan>=0.8.29->bertopic) (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/exouser/jupyter-env/lib/python3.12/site-packages (from pandas>=1.1.5->bertopic) (2.9.0.post0)
# Requirement already satisfied: narwhals>=1.15.1 in /home/exouser/jupyter-env/lib/python3.12/site-packages (from plotly>=4.7.0->bertopic) (2.25.0)
# Requirement already satisfied: packaging in /home/exouser/jupyter-env/lib/python3.12/site-packages (from plotly>=4.7.0->bertopic) (26.3)
# Requirement already satisfied: six>=1.5 in /home/exouser/jupyter-env/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=1.1.5->bertopic) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in /home/exouser/jupyter-env/lib/python3.12/site-packages (from scikit-learn>=1.0->bertopic) (3.6.0)
# Requirement already satisfied: transformers<6.0.0,>=5.0.0 in /home/exouser/jupyter-env/lib/python3.12/site-packages (from sentence-transformers>=0.4.1->bertopic) (5.16.1)
# Requirement already satisfied: tokenizers>=0.19 in /home/exouser/jupyter-env/lib/python3.12/site-packages (from sentence-transformers>=0.4.1->bertopic) (0.23.1)
# Requirement already satisfied: huggingface-hub<2.0.0,>=1.3.0 in /home/exouser/jupyter-env/lib/python3.12/site-packages (from sentence-transformers>=0.4.1->bertopic) (1.29.0)
# Requirement already satisfied: torch>=2.2 in /home/exouser/jupyter-env/lib/python3.12/site-packages (from sentence-transformers>=0.4.1->bertopic) (2.13.0)
# Requirement already satisfied: typing_extensions>=4.10.0 in /home/exouser/jupyter-env/lib/python3.12/site-packages (from sentence-transformers>=0.4.1->bertopic) (4.16.0)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in /home/exouser/jupyter-env/lib/python3.12/site-packages (from huggingface-hub<2.0.0,>=1.3.0->sentence-transformers>=0.4.1->bertopic) (8.5.0)
# Requirement already satisfied: filelock>=3.10.0 in /home/exouser/jupyter-env/lib/python3.12/site-packages (from huggingface-hub<2.0.0,>=1.3.0->sentence-transformers>=0.4.1->bertopic) (3.32.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/exouser/jupyter-env/lib/python3.12/site-packages (from huggingface-hub<2.0.0,>=1.3.0->sentence-transformers>=0.4.1->bertopic) (2026.7.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.2 in /home/exouser/jupyter-env/lib/python3.12/site-packages (from huggingface-hub<2.0.0,>=1.3.0->sentence-transformers>=0.4.1->bertopic) (1.6.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/exouser/jupyter-env/lib/python3.12/site-packages (from huggingface-hub<2.0.0,>=1.3.0->sentence-transformers>=0.4.1->bertopic) (0.28.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/exouser/jupyter-env/lib/python3.12/site-packages (from huggingface-hub<2.0.0,>=1.3.0->sentence-transformers>=0.4.1->bertopic) (6.0.3)
# Requirement already satisfied: anyio in /home/exouser/jupyter-env/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=1.3.0->sentence-transformers>=0.4.1->bertopic) (4.14.2)
# Requirement already satisfied: certifi in /home/exouser/jupyter-env/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=1.3.0->sentence-transformers>=0.4.1->bertopic) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /home/exouser/jupyter-env/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=1.3.0->sentence-transformers>=0.4.1->bertopic) (1.0.9)
# Requirement already satisfied: idna in /home/exouser/jupyter-env/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=1.3.0->sentence-transformers>=0.4.1->bertopic) (3.19)
# Requirement already satisfied: h11>=0.16 in /home/exouser/jupyter-env/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=1.3.0->sentence-transformers>=0.4.1->bertopic) (0.16.0)
# Requirement already satisfied: regex>=2025.10.22 in /home/exouser/jupyter-env/lib/python3.12/site-packages (from transformers<6.0.0,>=5.0.0->sentence-transformers>=0.4.1->bertopic) (2026.7.19)
# Requirement already satisfied: typer in /home/exouser/jupyter-env/lib/python3.12/site-packages (from transformers<6.0.0,>=5.0.0->sentence-transformers>=0.4.1->bertopic) (0.27.2)
# Requirement already satisfied: safetensors>=0.8.0 in /home/exouser/jupyter-env/lib/python3.12/site-packages (from transformers<6.0.0,>=5.0.0->sentence-transformers>=0.4.1->bertopic) (0.8.0)
# Requirement already satisfied: setuptools>=77.0.3 in /home/exouser/jupyter-env/lib/python3.12/site-packages (from torch>=2.2->sentence-transformers>=0.4.1->bertopic) (84.0.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/exouser/jupyter-env/lib/python3.12/site-packages (from torch>=2.2->sentence-transformers>=0.4.1->bertopic) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/exouser/jupyter-env/lib/python3.12/site-packages (from torch>=2.2->sentence-transformers>=0.4.1->bertopic) (3.6.1)
# Requirement already satisfied: jinja2 in /home/exouser/jupyter-env/lib/python3.12/site-packages (from torch>=2.2->sentence-transformers>=0.4.1->bertopic) (3.1.6)
# Requirement already satisfied: cuda-toolkit==13.0.3 in /home/exouser/jupyter-env/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch>=2.2->sentence-transformers>=0.4.1->bertopic) (13.0.3.0)
# Requirement already satisfied: cuda-bindings<14,>=13.0.3 in /home/exouser/jupyter-env/lib/python3.12/site-packages (from torch>=2.2->sentence-transformers>=0.4.1->bertopic) (13.3.1)
# Requirement already satisfied: nvidia-cudnn-cu13==9.20.0.48 in /home/exouser/jupyter-env/lib/python3.12/site-packages (from torch>=2.2->sentence-transformers>=0.4.1->bertopic) (9.20.0.48)
# Requirement already satisfied: nvidia-cusparselt-cu13==0.8.1 in /home/exouser/jupyter-env/lib/python3.12/site-packages (from torch>=2.2->sentence-transformers>=0.4.1->bertopic) (0.8.1)
# Requirement already satisfied: nvidia-nccl-cu13==2.29.7 in /home/exouser/jupyter-env/lib/python3.12/site-packages (from torch>=2.2->sentence-transformers>=0.4.1->bertopic) (2.29.7)
# Requirement already satisfied: nvidia-nvshmem-cu13==3.4.5 in /home/exouser/jupyter-env/lib/python3.12/site-packages (from torch>=2.2->sentence-transformers>=0.4.1->bertopic) (3.4.5)
# Requirement already satisfied: triton==3.7.1 in /home/exouser/jupyter-env/lib/python3.12/site-packages (from torch>=2.2->sentence-transformers>=0.4.1->bertopic) (3.7.1)
# Requirement already satisfied: nvidia-cublas==13.1.1.3.* in /home/exouser/jupyter-env/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch>=2.2->sentence-transformers>=0.4.1->bertopic) (13.1.1.3)
# Requirement already satisfied: nvidia-cuda-nvrtc==13.0.88.* in /home/exouser/jupyter-env/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch>=2.2->sentence-transformers>=0.4.1->bertopic) (13.0.88)
# Requirement already satisfied: nvidia-cuda-runtime==13.0.96.* in /home/exouser/jupyter-env/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch>=2.2->sentence-transformers>=0.4.1->bertopic) (13.0.96)
# Requirement already satisfied: nvidia-cufft==12.0.0.61.* in /home/exouser/jupyter-env/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch>=2.2->sentence-transformers>=0.4.1->bertopic) (12.0.0.61)
# Requirement already satisfied: nvidia-nvjitlink<14,>=13.0.88 in /home/exouser/jupyter-env/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch>=2.2->sentence-transformers>=0.4.1->bertopic) (13.3.33)
# Requirement already satisfied: nvidia-cufile==1.15.1.6.* in /home/exouser/jupyter-env/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch>=2.2->sentence-transformers>=0.4.1->bertopic) (1.15.1.6)
# Requirement already satisfied: nvidia-cuda-cupti==13.0.85.* in /home/exouser/jupyter-env/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch>=2.2->sentence-transformers>=0.4.1->bertopic) (13.0.85)
# Requirement already satisfied: nvidia-curand==10.4.0.35.* in /home/exouser/jupyter-env/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch>=2.2->sentence-transformers>=0.4.1->bertopic) (10.4.0.35)
# Requirement already satisfied: nvidia-cusolver==12.0.4.66.* in /home/exouser/jupyter-env/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch>=2.2->sentence-transformers>=0.4.1->bertopic) (12.0.4.66)
# Requirement already satisfied: nvidia-cusparse==12.6.3.3.* in /home/exouser/jupyter-env/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch>=2.2->sentence-transformers>=0.4.1->bertopic) (12.6.3.3)
# Requirement already satisfied: nvidia-nvtx==13.0.85.* in /home/exouser/jupyter-env/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch>=2.2->sentence-transformers>=0.4.1->bertopic) (13.0.85)
# Requirement already satisfied: cuda-pathfinder>=1.4.2 in /home/exouser/jupyter-env/lib/python3.12/site-packages (from cuda-bindings<14,>=13.0.3->torch>=2.2->sentence-transformers>=0.4.1->bertopic) (1.8.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/exouser/jupyter-env/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=2.2->sentence-transformers>=0.4.1->bertopic) (1.3.0)
# Collecting numba>=0.51.2 (from umap-learn>=0.5.0->bertopic)
#   Downloading numba-0.67.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.7 kB)
# Collecting pynndescent>=0.5 (from umap-learn>=0.5.0->bertopic)
#   Using cached pynndescent-0.6.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/exouser/jupyter-env/lib/python3.12/site-packages (from jinja2->torch>=2.2->sentence-transformers>=0.4.1->bertopic) (3.0.3)
# Requirement already satisfied: shellingham>=1.3.0 in /home/exouser/jupyter-env/lib/python3.12/site-packages (from typer->transformers<6.0.0,>=5.0.0->sentence-transformers>=0.4.1->bertopic) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /home/exouser/jupyter-env/lib/python3.12/site-packages (from typer->transformers<6.0.0,>=5.0.0->sentence-transformers>=0.4.1->bertopic) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /home/exouser/jupyter-env/lib/python3.12/site-packages (from typer->transformers<6.0.0,>=5.0.0->sentence-transformers>=0.4.1->bertopic) (0.0.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/exouser/jupyter-env/lib/python3.12/site-packages (from rich>=13.8.0->typer->transformers<6.0.0,>=5.0.0->sentence-transformers>=0.4.1->bertopic) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/exouser/jupyter-env/lib/python3.12/site-packages (from rich>=13.8.0->typer->transformers<6.0.0,>=5.0.0->sentence-transformers>=0.4.1->bertopic) (2.21.0)
# Requirement already satisfied: mdurl~=0.1 in /home/exouser/jupyter-env/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers<6.0.0,>=5.0.0->sentence-transformers>=0.4.1->bertopic) (0.1.2)
# Using cached bertopic-0.17.4-py3-none-any.whl (154 kB)
# Using cached hdbscan-0.8.44-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (5.9 MB)
# Downloading llvmlite-0.49.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (59.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.9/59.9 MB 17.7 MB/s  0:00:03 eta 0:00:010:00:01
# Downloading plotly-7.0.0-py3-none-any.whl (9.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 50.5 MB/s  0:00:00
# Using cached umap_learn-0.5.12-py3-none-any.whl (91 kB)
# Downloading numba-0.67.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 50.3 MB/s  0:00:00
# Using cached pynndescent-0.6.0-py3-none-any.whl (73 kB)
# Installing collected packages: plotly, llvmlite, numba, pynndescent, hdbscan, umap-learn, bertopic
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [bertopic]━━ 6/7 [bertopic]bscan]]
# Successfully installed bertopic-0.17.4 hdbscan-0.8.44 llvmlite-0.49.0 numba-0.67.0 plotly-7.0.0 pynndescent-0.6.0 umap-learn-0.5.12
# Note: you may need to restart the kernel to use updated packages.

# %%
#imports
import spacy
import scispacy
import timeit
import pandas as pd
import os
from pathlib import Path
from collections import defaultdict
from sentence_transformers import SentenceTransformer
from bertopic import BERTopic
from sklearn.feature_extraction.text import CountVectorizer
from collections import Counter
import plotly.express as px

# %%
#load term parser
nlp = spacy.load("en_core_sci_lg")

# %%
#change this to live file ingest later
#vectorizer = CountVectorizer(lowercase=True,)
file_path = Path.cwd().parent / "archs4metadata/COHORT|study=OSD-770|spaceflight=Space Flight_hits.csv"

#md_df = pd.read_parquet(file_path) if file_path.suffix == ".parquet" else pd.read_csv(file_path)
md_df = pd.read_csv(file_path)

idx = defaultdict(set) #may want to cache later if it gets big

# %%
def _add_spacy_terms(): # adds spacy terms to dataframe, returns list of flat terms of all tokens of all rows
    md_df['spacey_terms'] = md_df.apply(lambda _: [], axis=1)

    for row in md_df.itertuples():
        doc = nlp(row.geo_summary)
        for ent in doc.ents:
            term = ent.text.split()
            row.spacey_terms.extend(term)
            for t in term:
                idx[t].add(row.gse)
            
    
    return [item for lst in md_df["spacey_terms"] for item in lst]


def _update_idx(): #updates the term:journal it came from
    
    analyzer = vectorizer.build_analyzer()
    new_idx = defaultdict(set)

    for term,doc_ids in idx.items():
        tokenized = analyzer(term)
        for token in tokenized:
            new_idx[token].update(doc_ids)

    return new_idx  
    
def _add_journals(cl_df): #adds the list of journals that correspond to the 'Representation' words to the dataframe
     cl_df['journals'] = cl_df.apply(lambda _: [], axis=1)
     cl_df["Representation"] = cl_df["Representation"].apply(lambda lst: [x for x in lst if x])

     for row in cl_df.itertuples():
        
        
        for term in row.Representation:
            
            if term in idx:
               row.journals.extend(list(idx[term]))
            else:
                  print(f"term {term} not found in index")
     
     return cl_df   

'''
#clusters the samples in the provided dataframe. currently not set up to input a dataframe. 
returns the Bertopic model and the cluster dataframe. The cluster dataframe contains the results of the model.get_topic_info
as well as the journals associated with that cluster. 
'''
def cluster_sample(): 
    global idx
    flat_terms = _add_spacy_terms()
    vectorizer.fit(flat_terms)
    idx = _update_idx()
    model = SentenceTransformer('allenai/biomed_roberta_base')
    topic_model = BERTopic(vectorizer_model=vectorizer, embedding_model=model)
    topics,probs = topic_model.fit_transform(flat_terms)
    clusters = _add_journals(topic_model.get_topic_info())   
    return topic_model,clusters

'''
?
'''
def get_cluster_distribution(clusters,cluster_idx): #returns the journal percent distribution of every cluster
    journals = clusters.iloc[cluster_idx].journals
    cnts = Counter(journals)
   
    total = len(journals)

    percent_dist =  {name: (count / total) * 100 for name, count in cnts.items()}
    return percent_dist

def get_cluster_counts(clusters,cluster_idx): #returns the number of journals in the clusters
    journals = clusters.iloc[cluster_idx].journals
    cnts = Counter(journals)
    cnts = dict(cnts)
    return cnts


def get_top_cluster_distribution(clusters,n=5):
    top_clusters = clusters.head(n)
    distributions = {}
    for idx, row in top_clusters.iterrows():
        distributions[row.Topic] = get_cluster_distribution(clusters,idx)
    return distributions

'''
returns a dictionary of journal: number of times it appears
'''
def get_top_journals(clusters,n=5):
    
    top_clusters = clusters.head(n).iloc[1:] #skip outliers
    overall_cnts = defaultdict(int)
    for idx, row in top_clusters.iterrows():
       # print(f"Processing cluster {row.Topic} at index {idx}")
        journal_counts = get_cluster_counts(clusters,idx)
       # print(f"Journal counts for cluster {row.Topic}: {journal_counts}")
        for journal, count in journal_counts.items():
            #print(f"Adding {count} to overall count for journal {journal}")
            overall_cnts[journal] += count
    
    return overall_cnts

'''
returns a dataframe with the journals and what percentage they take up out of all the journals
'''
def get_top_journal_distribution(clusters): 
    top_cnt_dict = get_top_journals(clusters)
    total = sum(top_cnt_dict.values())
    percent_dist = {name: (count / total) * 100 for name, count in top_cnt_dict.items()}
    return pd.DataFrame(percent_dist)

# %%
model,clusters = cluster_sample() #47s no gpu on VM
# Out:
# Loading weights: 100%|██████████| 199/199 [00:00<00:00, 28183.91it/s]
# [transformers] RobertaModel LOAD REPORT from: allenai/biomed_roberta_base
# Key                       | Status     |  |
# --------------------------+------------+--+-
# lm_head.layer_norm.bias   | UNEXPECTED |  |
# lm_head.bias              | UNEXPECTED |  |
# lm_head.decoder.weight    | UNEXPECTED |  |
# lm_head.dense.bias        | UNEXPECTED |  |
# lm_head.dense.weight      | UNEXPECTED |  |
# lm_head.layer_norm.weight | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
model.get_topic_info().head(15)

# %%
top_j = get_top_journals(clusters)
jour_dict = get_top_journal_distribution(clusters)
jour_dist = pd.DataFrame(list(get_top_journal_distribution(clusters).items()),columns=['Journal','Percentage'])

# %%
jour_dist
# Out:
#      Journal  Percentage
# 0  GSE100505   48.648649
# 1  GSE103202   16.216216
# 2  GSE134241   35.135135

# %%
pd.DataFrame(get_top_cluster_distribution(clusters)) #note: includes outliers as -1 index
# Out:
#              -1         0     1     2     3
# GSE134241  25.0  15.384615  25.0  60.0  40.0
# GSE103202  25.0  30.769231  25.0  10.0   NaN
# GSE100505  50.0  53.846154  50.0  30.0  60.0

# %%
list(jour_dict.keys())
# Out:
# ['GSE100505', 'GSE103202', 'GSE134241']

# %%
list(jour_dict.items())
# Out:
# [('GSE100505', 48.64864864864865),
#  ('GSE103202', 16.216216216216218),
#  ('GSE134241', 35.13513513513514)]

# %%
def _plot_dist(dist):
    fig = px.pie(
    names = list(jour_dict.keys()),
    values = list(jour_dict.values()),
   
    title="Percentage Breakdown of Journals",
    )

    fig.show(renderer="browser")

# %%
_plot_dist(jour_dist)

# %%
def save_cluster_data(clusters, filename="cluster_data.csv"):
    clusters.to_csv(filename, index=False)

# %%
save_cluster_data(clusters, filename="COHORT|study=OSD-770|spaceflight=Space_Flight_top10hits_clusters.csv")

# %%
def compare_ground_spaceflight(clusters_ground,clusters_spaceflight):
    #see how much the clusters overlap between the two datasets
    #show common clusters, unique clusters, and distribution of journals in each cluster
    

    #create a set of intersection of clusters
    common_clusters = set(clusters_ground["Name"]).intersection(set(clusters_spaceflight["Name"]))
    unique_clusters_ground = set(clusters_ground["Name"]).difference(set(clusters_spaceflight["Name"]))
    unique_clusters_spaceflight = set(clusters_spaceflight["Name"]).difference(set(clusters_ground["Name"]))

    common_journals =   set(clusters_ground["journals"]).intersection(set(clusters_spaceflight["journals"]))
    unique_journals1 = set(clusters_ground["journals"]).difference(set(clusters_spaceflight["journals"]))
    unique_journals2 = set(clusters_spaceflight["journals"]).difference(set(clusters_ground["journals"]))

    #create a dataframe with the information
    comparison_dict ={
        "common_clusters": list(common_clusters),
        "unique_clusters_ground_control": list(unique_clusters_ground),
        "unique_clusters_spaceflight": list(unique_clusters_spaceflight),
        "common_journals": list(common_journals),
        "unique_journals_ground_control": list(unique_journals1),
        "unique_journals_spaceflight": list(unique_journals2)
    }
   
    
                     
                                                



    return comparison_dict

# %%
# !ls
# Out:
# 'COHORT|study=OSD-100|spaceflight=Ground_Control_top10hits_clusters.csv'
# 'COHORT|study=OSD-100|spaceflight=Space_Flight_top10hits_clusters.csv'
# 'COHORT|study=OSD-770|spaceflight=Ground Control_top10hits_clusters.csv'
# 'COHORT|study=OSD-770|spaceflight=Space_Flight_top10hits_clusters.csv'
#  cluster_metadata.ipynb
#  requirements.txt

# %%
import os
print(os.getcwd())
# Out:
# /home/exouser/Desktop/bridge-rna/clustering

# %%
ground_file_path = 'COHORT|study=OSD-100|spaceflight=Ground_Control_top10hits_clusters.csv' 
spaceflight_file_path = 'COHORT|study=OSD-100|spaceflight=Space_Flight_top10hits_clusters.csv'



ground_df = pd.read_csv(ground_file_path)
spaceflight_df = pd.read_csv(spaceflight_file_path)

compare_dict = compare_ground_spaceflight(ground_df, spaceflight_df)
