# %%
#having issues with the libraries so let me try a simple example
# %pip freeze > packages_to_uninstall.txt

# %%
# %pip uninstall -y -r packages_to_uninstall.txt

# %%
# %pip install bertopic sentence-transformers scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install ipywidgets

# %%
import torch
from sentence_transformers import SentenceTransformer
from bertopic import BERTopic
import umap
import hdbscan

device = "cuda" if torch.cuda.is_available() else "cpu"
print("Using:", device)

# Embeddings on CUDA
embedding_model = SentenceTransformer("BAAI/bge-base-en-v1.5", device=device)

# CPU clustering (UMAP/HDBSCAN)
umap_model = umap.UMAP(n_neighbors=15, n_components=5, min_dist=0.0)
hdbscan_model = hdbscan.HDBSCAN(min_samples=10)

topic_model = BERTopic(
    embedding_model=embedding_model,
    umap_model=umap_model,
    hdbscan_model=hdbscan_model
)

docs = [
]

topics, probs = topic_model.fit_transform(docs)

print("Topics:", topics)
# Out:
# Using: cuda
# Loading weights: 100%|██████████████████████████████████████████████████████████████████████████████████████| 199/199 [00:00<00:00, 3265.67it/s]
# ...

# %%
import torch
print("CUDA available:", torch.cuda.is_available())
print("Device count:", torch.cuda.device_count())
print("Current device:", torch.cuda.current_device() if torch.cuda.is_available() else None)
# Out:
# CUDA available: True
# Device count: 1
# Current device: 0
